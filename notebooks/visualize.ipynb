# %% [markdown]
# #### Preprocess data

# %%
#!od3d platform run -p torque -c "od3d dataset setup -d co3dv1_zsp_10s"

# %%
# !od3d platform run -p torque -c "od3d dataset extract-meta -d co3dv1_zsp_10s"
# Out:
# 20371.38s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# INFO:od3d.cli._platform:Run command od3d platform rsync-configs -p torque
# INFO:od3d.cli._platform:
# INFO:od3d.cli._platform:/home/heisenberg/Thesis_repo/od3d/venv_od3d/lib/python3.8/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'defaults': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# INFO:od3d.cli._platform:Run command rsync -avrzP /home/heisenberg/Thesis_repo/od3d/config/credentials/default.yaml torque:/misc/student/srinivap/git_repo/od3d/config/credentials/default.yaml
# INFO:od3d.cli._platform:sending incremental file list
#
# INFO:od3d.cli._platform:
#
# INFO:od3d.cli._platform:sent 75 bytes  received 12 bytes  34.80 bytes/sec
#
# INFO:od3d.cli._platform:total size is 88  speedup is 1.01
#
# INFO:od3d.cli._platform:Return Code 0
# INFO:od3d.cli._platform:Run command rsync -avrzP /home/heisenberg/Thesis_repo/od3d/config/platform/torque.yaml torque:/misc/student/srinivap/git_repo/od3d/config/platform/local.yaml
# INFO:od3d.cli._platform:sending incremental file list
#
# INFO:od3d.cli._platform:torque.yaml
#
# INFO:od3d.cli._platform:
#
# INFO:od3d.cli._platform:            641 100%    0.00kB/s    0:00:00
#
# INFO:od3d.cli._platform:            641 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=0/1)
#
# INFO:od3d.cli._platform:
#
# INFO:od3d.cli._platform:sent 422 bytes  received 41 bytes  132.29 bytes/sec
#
# INFO:od3d.cli._platform:total size is 641  speedup is 1.38
#
# INFO:od3d.cli._platform:Return Code 0
#
# /home/heisenberg/Thesis_repo/od3d/venv_od3d/lib/python3.8/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'defaults': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# INFO:od3d.benchmark.run:Run command ssh torque "mkdir -p /home/srinivap/tmp"
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:Run command scp /home/heisenberg/tmp/run_od3d_dataset_extract-meta_-d_co3dv1_zsp_10s.sh torque:/home/srinivap/tmp/run_od3d_dataset_extract-meta_-d_co3dv1_zsp_10s.sh
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:Run command scp /home/heisenberg/tmp/config_od3d_dataset_extract-meta_-d_co3dv1_zsp_10s.yaml torque:/home/srinivap/tmp/config_od3d_dataset_extract-meta_-d_co3dv1_zsp_10s.yaml
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:Run command ssh torque "cd torque_jobs && qsub /home/srinivap/tmp/run_od3d_dataset_extract-meta_-d_co3dv1_zsp_10s.sh"
# INFO:od3d.benchmark.run:2536802.lmbtorque.informatik.uni-freiburg.de
#
# INFO:od3d.benchmark.run:

# %%
# !od3d platform run -p torque -c "od3d dataset preprocess -d co3dv1_zsp_10s"
# Out:
# 22524.16s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# INFO:od3d.cli._platform:Run command od3d platform rsync-configs -p torque
# INFO:od3d.cli._platform:
# INFO:od3d.cli._platform:/home/heisenberg/Thesis_repo/od3d/venv_od3d/lib/python3.8/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'defaults': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# INFO:od3d.cli._platform:Run command rsync -avrzP /home/heisenberg/Thesis_repo/od3d/config/credentials/default.yaml torque:/misc/student/srinivap/git_repo/od3d/config/credentials/default.yaml
# INFO:od3d.cli._platform:sending incremental file list
#
# INFO:od3d.cli._platform:
#
# INFO:od3d.cli._platform:sent 75 bytes  received 12 bytes  24.86 bytes/sec
#
# INFO:od3d.cli._platform:total size is 88  speedup is 1.01
#
# INFO:od3d.cli._platform:Return Code 0
# INFO:od3d.cli._platform:Run command rsync -avrzP /home/heisenberg/Thesis_repo/od3d/config/platform/torque.yaml torque:/misc/student/srinivap/git_repo/od3d/config/platform/local.yaml
# INFO:od3d.cli._platform:sending incremental file list
#
# INFO:od3d.cli._platform:
#
# INFO:od3d.cli._platform:sent 73 bytes  received 12 bytes  24.29 bytes/sec
#
# INFO:od3d.cli._platform:total size is 641  speedup is 7.54
#
# INFO:od3d.cli._platform:Return Code 0
#
# /home/heisenberg/Thesis_repo/od3d/venv_od3d/lib/python3.8/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'defaults': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# INFO:od3d.benchmark.run:Run command ssh torque "mkdir -p /home/srinivap/tmp"
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:Run command scp /home/heisenberg/tmp/run_od3d_dataset_preprocess_-d_co3dv1_zsp_10s.sh torque:/home/srinivap/tmp/run_od3d_dataset_preprocess_-d_co3dv1_zsp_10s.sh
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:Run command scp /home/heisenberg/tmp/config_od3d_dataset_preprocess_-d_co3dv1_zsp_10s.yaml torque:/home/srinivap/tmp/config_od3d_dataset_preprocess_-d_co3dv1_zsp_10s.yaml
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:
# INFO:od3d.benchmark.run:Run command ssh torque "cd torque_jobs && qsub /home/srinivap/tmp/run_od3d_dataset_preprocess_-d_co3dv1_zsp_10s.sh"
# INFO:od3d.benchmark.run:2536807.lmbtorque.informatik.uni-freiburg.de
#
# INFO:od3d.benchmark.run:

# %%
from od3d.datasets.co3d import CO3D
from od3d.cv.visual.show import show_scene2d

co3d = CO3D.create_by_name('co3dv1_zsp_10s')#, config={'preprocess' : {'tform_obj': {'enabled': False}}}) #, config={'categories': [category], 'aligned_name': aligned_name, 'sequences_count_max_per_category': sequences_count}) # co3d_no_zsp_20s_aligned #co3d_5s_no_zsp_labeled 'co3d_50s_no_zsp_aligned' 'co3dv1_10s_zsp_aligned' 'co3d_10s_zsp_aligned' 'co3dv1_10s_zsp_unlabeled'
categories = co3d.categories
sequences = co3d.get_sequences()

print('categories:', categories)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# /home/heisenberg/Thesis_repo/od3d/venv_od3d/lib/python3.8/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'defaults': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/heisenberg/Thesis_repo/od3d/notebooks/visualize.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/home/heisenberg/Thesis_repo/od3d/notebooks/visualize.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from od3d.datasets.co3d import CO3D
# ----> <a href='vscode-notebook-cell:/home/heisenberg/Thesis_repo/od3d/notebooks/visualize.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> co3d = CO3D.create_by_name('co3dv1_zsp_10s')#, config={'preprocess' : {'tform_obj': {'enabled': False}}}) #, config={'categories': [category], 'aligned_name': aligned_name, 'sequences_count_max_per_category': sequences_count}) # co3d_no_zsp_20s_aligned #co3d_5s_no_zsp_labeled 'co3d_50s_no_zsp_aligned' 'co3dv1_10s_zsp_aligned' 'co3d_10s_zsp_aligned' 'co3dv1_10s_zsp_unlabeled'
#       <a href='vscode-notebook-cell:/home/heisenberg/Thesis_repo/od3d/notebooks/visualize.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> categories = co3d.categories
#       <a href='vscode-notebook-cell:/home/heisenberg/Thesis_repo/od3d/notebooks/visualize.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> sequences = co3d.get_sequences()
#
# File ~/Thesis_repo/od3d/src/od3d/datasets/dataset.py:67, in OD3D_Dataset.create_by_name(cls, name, config)
#      65     config_loaded = OmegaConf.merge(config_loaded, config)
#      66     OmegaConf.set_struct(config_loaded, True)
# ---> 67 return cls.create_from_config(config_loaded)
#
# File ~/Thesis_repo/od3d/src/od3d/datasets/dataset.py:53, in OD3D_Dataset.create_from_config(cls, config, transform)
#      50     cls.extract_meta(config=config)
#      52 keys = inspect.getfullargspec(cls.__init__)[0][1:]
# ---> 53 od3d_dataset = cls(**dict((key, config.get(key)) for key in keys if config.get(key, None) is not None), transform=transform)
#      55 if config.get("preprocess", False):
#      56     od3d_dataset.preprocess(config_preprocess=config.preprocess)
#
# File ~/Thesis_repo/od3d/src/od3d/datasets/co3d/dataset.py:48, in CO3D.__init__(self, name, modalities, path_raw, path_preprocess, categories, dict_nested_frames, dict_nested_frames_ban, frames_count_max_per_sequence, transform, index_shift, subset_fraction, mesh_type, mesh_feats_type, mesh_feats_dist_reduce_type)
#      39 def __init__(self, name: str, modalities: List[OD3D_FRAME_MODALITIES], path_raw: Path, path_preprocess: Path,
#      40              categories: List[CO3D_CATEGORIES]=None,
#      41              dict_nested_frames: Dict[str, Dict[str, List[str]]]=None,
#    (...)
#      45              mesh_feats_type=OD3D_MESH_FEATS_TYPES.M_DINOV2_VITB14_FROZEN_BASE_NO_NORM_T_CENTERZOOM512_R_ACC,
#      46              mesh_feats_dist_reduce_type=OD3D_MESH_FEATS_DIST_REDUCE_TYPES.MIN_AVG,):
# ---> 48     super().__init__(categories=categories, name=name, modalities=modalities, path_raw=path_raw,
#      49                      path_preprocess=path_preprocess, transform=transform, subset_fraction=subset_fraction,
#      50                      index_shift=index_shift, dict_nested_frames=dict_nested_frames,
#      51                      dict_nested_frames_ban=dict_nested_frames_ban,
#      52                      frames_count_max_per_sequence=frames_count_max_per_sequence)
#      54     self.mesh_type = mesh_type
#      55     self.mesh_feats_type = mesh_feats_type
#
# File ~/Thesis_repo/od3d/src/od3d/datasets/dataset.py:410, in OD3D_SequenceDataset.__init__(self, name, modalities, path_raw, path_preprocess, categories, dict_nested_frames, dict_nested_frames_ban, transform, index_shift, subset_fraction, frames_count_max_per_sequence)
#     408                 dict_nested_frames_seqs_filtered[category][sequence_name] = []
#     409 dict_nested_frames = dict_nested_frames_seqs_filtered
# --> 410 super().__init__(categories=categories, dict_nested_frames=dict_nested_frames, dict_nested_frames_ban=dict_nested_frames_ban, name=name, modalities=modalities, path_raw=path_raw,
#     411                  path_preprocess=path_preprocess, transform=transform, index_shift=index_shift,
#     412                  subset_fraction=subset_fraction)
#
# File ~/Thesis_repo/od3d/src/od3d/datasets/dataset.py:94, in OD3D_Dataset.__init__(self, name, modalities, path_raw, path_preprocess, categories, transform, index_shift, subset_fraction, dict_nested_frames, dict_nested_frames_ban)
#      91 self.categories = categories if categories is not None else self.all_categories
#      93 logger.info('completing nested frames..., can take up to 500 seconds...')
# ---> 94 dict_nested_frames = self.frame_type.meta_type.complete_nested_metas(path_meta=self.path_meta,
#      95                                                                      dict_nested_metas=dict_nested_frames,
#      96                                                                      dict_nested_metas_ban=
#      97                                                                      dict_nested_frames_ban)
#     100 dict_nested_frames = self.filter_dict_nested_frames(dict_nested_frames)
#     102 logger.info('unrolling nested frames...')
#
# File ~/Thesis_repo/od3d/src/od3d/datasets/meta.py:93, in OD3D_Meta.complete_nested_metas(cls, path_meta, dict_nested_metas, parent_key, separator, dict_nested_metas_ban)
#      91 elif isinstance(value,  Dict) or isinstance(value, DictConfig):
#      92     if dict_nested_metas_ban is None or key not in dict_nested_metas_ban:
# ---> 93         dict_nested_frames_completed[key] = cls.complete_nested_metas(path_meta=path_meta,
#      94                                                                       parent_key=new_key,
#      95                                                                       dict_nested_metas=value)
#      96     elif dict_nested_metas_ban[key] is not None:
#      97         dict_nested_frames_completed[key] = cls.complete_nested_metas(path_meta=path_meta,
#      98                                                                       parent_key=new_key,
#      99                                                                       dict_nested_metas=value,
#     100                                                                       dict_nested_metas_ban=dict_nested_metas_ban[key])
#
# File ~/Thesis_repo/od3d/src/od3d/datasets/meta.py:68, in OD3D_Meta.complete_nested_metas(cls, path_meta, dict_nested_metas, parent_key, separator, dict_nested_metas_ban)
#      66 new_key = f"{parent_key}{separator}{key}" if parent_key else key
#      67 if value is None:
# ---> 68     dir_fpaths = list(
#      69         cls.get_path_metas(path_meta=path_meta).joinpath(new_key).iterdir())
#      70     if dir_fpaths[0].is_dir():
#      71         if dict_nested_metas_ban is None or key not in dict_nested_metas_ban:
#
# File /usr/lib/python3.8/pathlib.py:1122, in Path.iterdir(self)
#    1120 if self._closed:
#    1121     self._raise_closed()
# -> 1122 for name in self._accessor.listdir(self):
#    1123     if name in {'.', '..'}:
#    1124         # Yielding a path object for these makes little sense
#    1125         continue
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/heisenberg/Thesis_repo/dataset_preprocess/CO3Dv1_Preprocess/meta/frames/bicycle/397_49943_98337'
